# %%
import chromadb

client = chromadb.Client()

# %%
collection = client.create_collection("news_article")

# %%
collection.add(
    ids = ['id1', 'id2', 'id3', 'id4'],
    documents = [
        "Apple is leading in a smart phone game with iPhone sales up by 35%",
        "Tesla booked a minor profit of 1 billion $ in Q2",
        "Apples are high in fiber, vitamin C, and various antioxidants",
        "SpaceX got NASA contract worth 10 billion $",
    ]
)
# Out:
# /Users/jayantadey/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|█| 79

# %%
data = collection.get(
    include = ['documents', 'embeddings', 'metadatas']
)

for i, emb in enumerate(data['embeddings']):
    print(f"\nDocument {i+1}")
    print("Text:",data['documents'][i])
    print('Embedding length:', len(emb))
    print("First 10 values", emb[:10])
# Out:
# Document 1
# Text: Apple is leading in a smart phone game with iPhone sales up by 35%
# Embedding length: 384
# First 10 values [ 0.03640451  0.01021038  0.08642429 -0.12735225 -0.0189593   0.00309629
#   0.01671753  0.05566164  0.02376821  0.11325456]
#
# Document 2
# Text: Tesla booked a minor profit of 1 billion $ in Q2
# Embedding length: 384
# First 10 values [ 0.03228299  0.0888853   0.02695833  0.0744426  -0.06773707 -0.03529567
#  -0.02407433  0.10166307  0.02283018  0.02386425]
#
# Document 3
# Text: Apples are high in fiber, vitamin C, and various antioxidants
# Embedding length: 384
# First 10 values [ 0.04512434 -0.03145012  0.01100096  0.08058894  0.00119946  0.02187005
#  -0.00926969 -0.01325605  0.00425184  0.02350497]
#
# Document 4
# Text: SpaceX got NASA contract worth 10 billion $
# Embedding length: 384
# First 10 values [-0.02309864  0.03526219  0.06101783 -0.02734385 -0.08042095 -0.02970154
#   0.07421499  0.05592677  0.02907893  0.07048379]

# %%
results = collection.query(
    query_texts=["This is a query related to Elon Musk"],
    n_results=2
)
print(results)
# Out:
# {'ids': [['id2', 'id4']], 'embeddings': None, 'documents': [['Tesla booked a minor profit of 1 billion $ in Q2', 'SpaceX got NASA contract worth 10 billion $']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.5166927576065063, 1.559833288192749]]}

# %%
results = collection.query(
    query_texts=["I love iPad"],
    n_results=2
)
print(results)
# Out:
# {'ids': [['id1', 'id3']], 'embeddings': None, 'documents': [['Apple is leading in a smart phone game with iPhone sales up by 35%', 'Apples are high in fiber, vitamin C, and various antioxidants']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.4372704029083252, 1.6695858240127563]]}
